# %%
import pandas as pd

chunk_iter = pd.read_csv("../data/raw/accepted_2007_to_2018Q4.csv", chunksize=200_000)

# %%
df_sample = next(chunk_iter)   # loads first 200k rows for EDA
df_sample.head(30)
# Out:
# /var/folders/bc/_h0z1r_n7xsczt7nbblx6sxr0000gn/T/ipykernel_96671/1736112426.py:1: DtypeWarning: Columns (19,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sample = next(chunk_iter)   # loads first 200k rows for EDA
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0   68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1   68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2   68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3   66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4   68476807        NaN    10400.0      10400.0          10400.0   60 months
# 5   68426831        NaN    11950.0      11950.0          11950.0   36 months
# 6   68476668        NaN    20000.0      20000.0          20000.0   36 months
# 7   67275481        NaN    20000.0      20000.0          20000.0   36 months
# ...
